# %% [markdown]
# <a href="https://colab.research.google.com/github/Afaf-yunas11/Roman_Urdu_Code_Mixed_Emotion_Analysis/blob/Eman_Branch/NLP_intial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Now you can access your NLP_dataset folder
import os

# List contents of your NLP_dataset folder
nlp_path = '/content/drive/MyDrive/NLP_dataset/'
if os.path.exists(nlp_path):
    print("Files in NLP_dataset folder:")
    print(os.listdir(nlp_path))
else:
    print("NLP_dataset folder not found")
# Out:
# Files in NLP_dataset folder:
# ['joy_sent.txt', 'sadness_sent.txt']

# %%
import pandas as pd
from pathlib import Path

nlp_path = Path('/content/drive/MyDrive/NLP_dataset/')
joy_file = nlp_path / 'joy.txt'
sad_file = nlp_path / 'sadness.txt'

def txt_to_df(txt_path, label):
    with open(txt_path, 'r', encoding='utf-8') as f:
        lines = [line.strip() for line in f if line.strip()]
    return pd.DataFrame({'text': lines, 'label': label})

df_joy = txt_to_df(joy_file, 'joy')
df_sad = txt_to_df(sad_file, 'sadness')

df = pd.concat([df_joy, df_sad], ignore_index=True).sample(frac=1, random_state=42).reset_index(drop=True)
print(df.shape)
df.head()
# Save to Drive for later
df.to_csv(nlp_path / 'emotion_dataset.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2189486795.py in <cell line: 0>()
#      11     return pd.DataFrame({'text': lines, 'label': label})
#      12
# ---> 13 df_joy = txt_to_df(joy_file, 'joy')
#      14 df_sad = txt_to_df(sad_file, 'sadness')
#      15
#
# /tmp/ipython-input-2189486795.py in txt_to_df(txt_path, label)
#       7
#       8 def txt_to_df(txt_path, label):
# ----> 9     with open(txt_path, 'r', encoding='utf-8') as f:
#      10         lines = [line.strip() for line in f if line.strip()]
#      11     return pd.DataFrame({'text': lines, 'label': label})
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/NLP_dataset/joy.txt'

# %% [markdown]
# # New Section
